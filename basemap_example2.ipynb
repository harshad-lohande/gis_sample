# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
import warnings; warnings.simplefilter('ignore')

# %%
fig = plt.figure(figsize=(8,8))
map = Basemap(llcrnrlon=-0.5,llcrnrlat=39.8,urcrnrlon=4.,urcrnrlat=43.,
             resolution='h', projection='cass', lat_0 = 39.5, lon_0 = 1)
map.shadedrelief()
map.drawcountries(color='gray')
map.drawcoastlines(color='gray')
map.drawstates(color='gray')

map.readshapefile('sample_files/comarques', 'comarques')

lightning_info = map.readshapefile('sample_files/lightnings', 'lightnings')

print lightning_info

for info, lightning in zip(map.lightnings_info, map.lightnings):
    if float(info['amplitude']) < 0:
        marker = '_'
    else:
        marker = '+'
    map.plot(lightning[0], lightning[1], marker=marker, color='m', markersize=8, markeredgewidth=2)

plt.show()
# Out:
# (308, 1, [-1.1545805, 36.628124, 0.0, 0.0], [7.9286885, 42.402252, 0.0, 0.0])

# %%
fig = plt.figure(figsize=(8,8))
map = Basemap(llcrnrlon=-0.3,llcrnrlat=39.8,urcrnrlon=5.,urcrnrlat=43.,
             resolution='f', projection='cass', lat_0 = 39.5, lon_0 = 1)
map.shadedrelief()
map.drawcountries(color='gray')
map.drawcoastlines(color='gray')
map.drawstates(color='gray')

map.readshapefile('sample_files/comarques', 'comarques')

lightning_info = map.readshapefile('sample_files/lightnings', 'lightnings')

print lightning_info

for info, lightning in zip(map.lightnings_info, map.lightnings):
    if float(info['amplitude']) < 0:
        marker = '_'
    else:
        marker = '+'
    map.plot(lightning[0], lightning[1], marker=marker, color='m', markersize=8, markeredgewidth=2)

plt.show()
# Out:
# (308, 1, [-1.1545805, 36.628124, 0.0, 0.0], [7.9286885, 42.402252, 0.0, 0.0])

# %%
import pandas as pd
import numpy as np
wf_tweet_cord = pd.read_csv('wildfire_sentiment_analysis_working.csv')

# %%
lat = wf_tweet_cord['Lat'].values
lon = wf_tweet_cord['Long'].values

# %%
# draw the map background
fig = plt.figure(figsize=(15,12))
# The transverse aspect of the equidistant cassindrical projection. The globe is first rotated so the \
# central meridian becomes the “equator”, and then the normal equidistant cylindrical projection is applied
m = Basemap(llcrnrlon=-0.5,llcrnrlat=39.8,urcrnrlon=4.,urcrnrlat=43.,
             resolution='h', projection='cass', lat_0 = 39.5, lon_0 = 1)
m.shadedrelief()
m.drawcountries(color='gray')
m.drawcoastlines(color='gray')
m.drawstates(color='gray')

# draw parallels (latitude)
parallels = np.arange(0.,90.,10.)
m.drawparallels(parallels, labels=[1,0,0,0], fontsize=10)

# draw meridians (longitude)
meridians = np.arange(180.,360.,10.)
m.drawmeridians(meridians=meridians, labels=[0,0,0,1], fontsize=10)

# plot scatter points on map
#m.scatter(lon, lat, latlon=True, alpha=0.4, color='b', s=6)
# Out:
# {}

# %%
fig = plt.figure(figsize=(15,12))

test_map = Basemap(llcrnrlon=-102.7461664,llcrnrlat=31.42005078,urcrnrlon=-100.39704338, urcrnrlat=34.87992202, epsg = 2275,resolution='i',projection='merc',lon_0=14.8,lat_0=47.2)

test_map.arcgisimage(service='ESRI_StreetMap_World_2D', xpixels = 12000, verbose= True)
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/ESRI_StreetMap_World_2D/MapServer/export?bbox=266539.333951,2343567.98719,986963.561993,3602941.75192&bboxSR=2275&imageSR=2275&size=12000,20977&dpi=96&format=png32&f=image
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-24-54f9130efb8f> in <module>()
#       3 test_map = Basemap(llcrnrlon=-102.7461664,llcrnrlat=31.42005078,urcrnrlon=-100.39704338, urcrnrlat=34.87992202, epsg = 2275,resolution='i',projection='merc',lon_0=14.8,lat_0=47.2)
#       4
# ----> 5 test_map.arcgisimage(service='ESRI_StreetMap_World_2D', xpixels = 12000, verbose= True)
#
# C:\Users\LohanDH1\AppData\Local\Continuum\anaconda3\envs\py27\lib\site-packages\mpl_toolkits\basemap\__init__.pyc in arcgisimage(self, server, service, xpixels, ypixels, dpi, verbose, **kwargs)
#    4268         if verbose: print basemap_url
# ...

# %%
import urllib2

# %%
proxy_support = urllib2.ProxyHandler({"https":"https://172.29.206.230:8080"})
opener = urllib2.build_opener(proxy_support)
urllib2.install_opener(opener)
urllib2.urlopen("http://www.google.com").read()
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-22-4c2755d425fc> in <module>()
#       2 opener = urllib2.build_opener(proxy_support)
#       3 urllib2.install_opener(opener)
# ----> 4 urllib2.urlopen("http://www.google.com").read()
#
# C:\Users\LohanDH1\AppData\Local\Continuum\anaconda3\envs\py27\lib\urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# C:\Users\LohanDH1\AppData\Local\Continuum\anaconda3\envs\py27\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# ...

# %%
urllib2.urlopen("http://www.google.com").read()
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-21-61c3b01512f4> in <module>()
# ----> 1 urllib2.urlopen("http://www.google.com").read()
#
# C:\Users\LohanDH1\AppData\Local\Continuum\anaconda3\envs\py27\lib\urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# C:\Users\LohanDH1\AppData\Local\Continuum\anaconda3\envs\py27\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# C:\Users\LohanDH1\AppData\Local\Continuum\anaconda3\envs\py27\lib\urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
# ...
